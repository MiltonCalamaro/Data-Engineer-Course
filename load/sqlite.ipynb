# %%
# Importa pandas y sqlite3
import pandas as pd
import sqlite3

# Crea una conexión a la base de datos SQLite
con = sqlite3.connect("newspaper.db")
# Usa read_sql_query de pandas para extraer el resultado
# de la consulta a un DataFrame
df = pd.read_sql_query("SELECT * from articles", con)
print(df.head())

# No te olvides de cerrar la conexión
con.close()
# Out:
# Empty DataFrame
# Columns: [id, body, host, newspaper_uid, n_tokens_body, n_tokens_title, title, url]
# Index: []

# %%
con = sqlite3.connect("newspaper.db")
res = con.execute(
    "SELECT body FROM articles ")
con.execute("INSERT INTO articles values('h','b','c','d',1,2,'e','h')")
con.commit()
con.close()

# %%
# Importa pandas y sqlite3
import pandas as pd
import sqlite3

# Crea una conexión a la base de datos SQLite
con = sqlite3.connect("newspaper.db")
# Usa read_sql_query de pandas para extraer el resultado
# de la consulta a un DataFrame
df = pd.read_sql_query("SELECT * from articles", con)
print(df.head())

# No te olvides de cerrar la conexión
con.close()
# Out:
#   id body host newspaper_uid  n_tokens_body  n_tokens_title title url
# 0  h    b    c             d              1               2     e   h

# %%
# Importa pandas y sqlite3
import pandas as pd
import sqlite3

# Crea una conexión a la base de datos SQLite
con = sqlite3.connect("newspaper.db")
# Usa read_sql_query de pandas para extraer el resultado
# de la consulta a un DataFrame
df = pd.read_sql_query("SELECT * from articles", con)
# No te olvides de cerrar la conexión
con.close()

df
# Out:
#                                    id  \
# 0    ec0c11f6a5181b83c86bc6d379848a3a
# 1    31d15d5b71df9089cbbf59f3e66494f1
# 2    f8fd3b4fa841f2626e41e7c6658c0577
# 3    aed4ae00183d1252de6fb50ef1c56e21
# 4    83376c56f28da1b7a519dd82e69dd4ab
# ..                                ...
# 106  c9ed0fc36eb322bbfd7fafc3038c5f06
# 107  740121c23d8849593d1c2180fe8ebdd6
# 108  670e2f5636a0daa9a83864ea256ae387
# 109  29066dd5c3ce7fc8b7fa2bb7f753cb18
# 110  9aa222ec9eddfec40d82c080b639d17e
#
#                                                   body  \
# 0      Le contamos que ayer en la Ciudad de México ...
# 1     La actriz Gal Gadot disfrutó de un paseo en u...
# 2     Toluca, Méx.— Desde hace más de 30 años que R...
# 3            googletag.cmd.push(function() {       ...
# 4            googletag.cmd.push(function() {       ...
# ..                                                 ...
# 106    Tabasco suma 3 mil 44 casos confirmados y 38...
# 107   “¡Campeón!”, le dice mucha gente a Armando He...
# 108    Alondra Marbán dejó de ir a La Villita, en C...
# 109  El infortunio alcanzó a un repartidor de produ...
# 110   0 % PULSO SOCIAL0 Elvis Presley fue todo un r...
#
#                        host newspaper_uid  n_tokens_body  n_tokens_title  \
# 0                      None   eluniversal            165               4
# 1            www.viveusa.mx   eluniversal            212               8
# 2    www.eluniversal.com.mx   eluniversal            258               3
# 3        www.unionpuebla.mx   eluniversal            221               5
# 4        www.unionedomex.mx   eluniversal            190               5
# ..                      ...           ...            ...             ...
# 106                    None   eluniversal            278               7
# 107                    None   eluniversal            169               4
# 108                    None   eluniversal            241               5
# 109        www.elgrafico.mx   eluniversal             96               8
# 110             de10.com.mx   eluniversal            391               6
#
#                                                  title  \
# 0                  Asilos, bajo la lupa de autoridades
# 1    gal gadot presume belleza con short de serpien...
# 2             Por Covid-19, ofrecen “bola” a domicilio
# 3    Carpeta de Experiencias. ¿Cómo integrarla y qu...
# 4    Municipios con coronavirus en Edomex | MAPA UNAM
# ..                                                 ...
# 106  Casos de Covid-19 en Yucatán, Quintana Roo, Ca...
# 107           Covid-19 golpeó bajo a Armando Hernández
# 108  “La gente no tiene con qué ir al doctor, muere...
# 109  conductor pierde el control y amputa piernas r...
# 110  el antes y despues de priscilla presley la uni...
#
#                                                    url
# 0        /metropoli/asilos-bajo-la-lupa-de-autoridades
# 1    https://www.viveusa.mx/showbiz/gal-gadot-presu...
# 2    https://www.eluniversal.com.mx/metropoli/por-c...
# 3    http://www.unionpuebla.mx/articulo/2020/04/27/...
# 4    http://www.unionedomex.mx/articulo/2020/04/28/...
# ..                                                 ...
# 106  /estados/casos-de-covid-19-en-yucatan-quintana...
# 107  /espectaculos/covid-19-golpeo-bajo-armando-her...
# 108  /nacion/la-gente-no-tiene-con-que-ir-al-doctor...
# 109  https://www.elgrafico.mx/la-roja/conductor-pie...
# 110  https://de10.com.mx/top-10/el-antes-y-despues-...
#
# [111 rows x 8 columns]
